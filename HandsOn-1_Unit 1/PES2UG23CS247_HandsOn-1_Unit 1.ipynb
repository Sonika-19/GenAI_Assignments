# %% [markdown]
# SRN : PES2UG23CS247
#
# Name : K L Sonika
#
# Section : D

# %%
from transformers import pipeline, set_seed, GPT2Tokenizer

# %%
import os
import nltk

# %%
file_path = "unit 1.txt"

# %%
try:
    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()
    print("File loaded successfully!")
except FileNotFoundError:
    print(f"Error: '{file_path}' not found.")
# Out:
# File loaded successfully!

# %%
print("--- Data Preview ---")
print(text[:500] + "...")
# Out:
# --- Data Preview ---
# Generative AI and Its Applications: A Foundational Briefing
#
# Executive Summary
#
# This document provides a comprehensive overview of Generative AI, synthesizing foundational concepts, technological underpinnings, and practical applications as outlined in the course materials from PES University. Generative AI represents a transformative subset of Artificial Intelligence focused on creating novel content, a capability primarily driven by the advent of Large Language Models (LLMs). The evolution of ...

# %%
set_seed(42)

# %% [markdown]
# Experiment 1: Text Generation

# %%
prompt = "Generative AI is a revolutionary technology that"

# %%
from transformers import pipeline

bert_gen = pipeline("text-generation", model="bert-base-uncased")
bert_gen(prompt, max_length=50, num_return_sequences=1)
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Generative AI is a revolutionary technology that................................................................................................................................................................................................................................................................'}]

# %%
roberta_gen = pipeline("text-generation", model="roberta-base")
roberta_gen(prompt, max_length=50, num_return_sequences=1)
# Out:
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Generative AI is a revolutionary technology that.s'}]

# %%
bart_gen = pipeline("text-generation", model="facebook/bart-base")
bart_gen(prompt, max_length=50, num_return_sequences=1)
# Out:
# Some weights of BartForCausalLM were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['lm_head.weight', 'model.decoder.embed_tokens.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Generative AI is a revolutionary technology that Longh spent butterfly butterfly butterfly backdoor Controlled CatholicClearoh backdoorGrade undesirablexxxxlla Scotlandxxxx Longh Controlled tinopic purchasing butterflyxxxx Assistancexxxx butterflyxxxx Gallup backdoorë Salam Salam MA tin tinFight doubtless� backdoor berries clicking propensity accurate accurate accurate Salam tinaum backdoorFightFight doubtless tin tin Scotlandforeseen forcefully Scotland propensity clicking clicking accurate MAFight tin MA propensity� MAFight MA MAëë backdoor purchasing berries ICE backdoor backdoor Cell purchasing backdoor Scotland doubtless doubtless purchasing backdoor tin Scotland rushingonga backdoor clicking backdoor MAFight doubtless Depend tin MA Depend tin doubtless tin backdoor backdoor RBI clicking anomaly backdoor doubtless MA MA doubtless doubtless doubtless Scotland backdoor doubtlessforeseen MA MA MAgly Products MA Salam Scotland Scotland backdoor MA MA summ doubtless doubtless clickingbindbind tin MA Fleet MA MA Products clicking clicking clicking Scotland doubtlessolphin MA Salam Salam tin tin clicking Scotland 640 Scotland dodging poison doubtless Scotland anomaly purchasing clicking clicking Salam purchasing Fleet backdoor clicking clicking doubtless clicking MA 640 backdoor Scotland clickingFight clicking doubtless doubtless Fleet doubtless doubtless Capitalism doubtless doubtless rushing MA doubtless tin 640 clicking 640 clicking doubtless Scotland purchasing doubtless anomaly tin Scotland clicking doubtless.): backdoor Capitalism rushing purchasing clicking doubtlessoo doubtless backdoor clickingKeeping doubtless backdoor MAchens doubtless anomaly Fleet Capitalism backdoor anomaly Fleet ScotlandPrem Scotland tin clicking anomaly Scotlandbind Scotland doubtless Scotland Capitalism doubtless clicking Scotland clicking tin Scotland backdoor tin MA clicking dodging'}]

# %% [markdown]
# Experiment 2: Masked Language Modeling (Fill-Mask)

# %%
bert_mask = pipeline("fill-mask", model="bert-base-uncased")
bert_mask("The goal of Generative AI is to [MASK] new content.")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.5396937131881714,
#   'token': 3443,
#   'token_str': 'create',
#   'sequence': 'the goal of generative ai is to create new content.'},
#  {'score': 0.15575705468654633,
#   'token': 9699,
#   'token_str': 'generate',
#   'sequence': 'the goal of generative ai is to generate new content.'},
#  {'score': 0.05405480042099953,
#   'token': 3965,
#   'token_str': 'produce',
#   'sequence': 'the goal of generative ai is to produce new content.'},
#  {'score': 0.04451539367437363,
#   'token': 4503,
#   'token_str': 'develop',
#   'sequence': 'the goal of generative ai is to develop new content.'},
#  {'score': 0.01757744885981083,
#   'token': 5587,
#   'token_str': 'add',
#   'sequence': 'the goal of generative ai is to add new content.'}]

# %%
roberta_mask = pipeline("fill-mask", model="roberta-base")
roberta_mask("The goal of Generative AI is to <mask> new content.")
# Out:
# Device set to use cpu
# [{'score': 0.37113314867019653,
#   'token': 5368,
#   'token_str': ' generate',
#   'sequence': 'The goal of Generative AI is to generate new content.'},
#  {'score': 0.36771294474601746,
#   'token': 1045,
#   'token_str': ' create',
#   'sequence': 'The goal of Generative AI is to create new content.'},
#  {'score': 0.08351416140794754,
#   'token': 8286,
#   'token_str': ' discover',
#   'sequence': 'The goal of Generative AI is to discover new content.'},
#  {'score': 0.02133510820567608,
#   'token': 465,
#   'token_str': ' find',
#   'sequence': 'The goal of Generative AI is to find new content.'},
#  {'score': 0.016521671786904335,
#   'token': 694,
#   'token_str': ' provide',
#   'sequence': 'The goal of Generative AI is to provide new content.'}]

# %%
bart_mask = pipeline("fill-mask", model="facebook/bart-base")
bart_mask("The goal of Generative AI is to <mask> new content.")
# Out:
# Device set to use cpu
# [{'score': 0.0746152326464653,
#   'token': 1045,
#   'token_str': ' create',
#   'sequence': 'The goal of Generative AI is to create new content.'},
#  {'score': 0.06571866571903229,
#   'token': 244,
#   'token_str': ' help',
#   'sequence': 'The goal of Generative AI is to help new content.'},
#  {'score': 0.060880016535520554,
#   'token': 694,
#   'token_str': ' provide',
#   'sequence': 'The goal of Generative AI is to provide new content.'},
#  {'score': 0.03593575954437256,
#   'token': 3155,
#   'token_str': ' enable',
#   'sequence': 'The goal of Generative AI is to enable new content.'},
#  {'score': 0.03319466486573219,
#   'token': 1477,
#   'token_str': ' improve',
#   'sequence': 'The goal of Generative AI is to improve new content.'}]

# %% [markdown]
# Experiment 3: Question Answering

# %%
question = "What are the risks?"
context = "Generative AI poses significant risks such as hallucinations, bias, and deepfakes."

# %%
bert_qa = pipeline("question-answering", model="bert-base-uncased")
bert_qa(question=question, context=context)
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# {'score': 0.015565985348075628,
#  'start': 11,
#  'end': 60,
#  'answer': 'AI poses significant risks such as hallucinations'}

# %%
roberta_qa = pipeline("question-answering", model="roberta-base")
roberta_qa(question=question, context=context)
# Out:
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# {'score': 0.013304589316248894,
#  'start': 43,
#  'end': 81,
#  'answer': 'as hallucinations, bias, and deepfakes'}

# %%
bart_qa = pipeline("question-answering", model="facebook/bart-base")
bart_qa(question=question, context=context)
# Out:
# Some weights of BartForQuestionAnswering were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# {'score': 0.0461971266195178, 'start': 72, 'end': 82, 'answer': 'deepfakes.'}
